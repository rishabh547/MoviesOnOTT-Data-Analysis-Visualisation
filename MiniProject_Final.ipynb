# %% [markdown]
# ## Mini Project - Data visualization using Python
# ### Dataset : Movies streaming on Ott Platforms
# ### Roll no. 1911104, 1911110, 1911122

# %%
#Checking directory
import os
print(os.getcwd())
# Out:
# C:\Users\PANDIT\Jupyter_Folder

# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Importing the dataset using pandas
df = pd.read_csv("MoviesOnOtt.csv")
df.head()
# Out:
#    Unnamed: 0  ID                           Title  Year  Age  IMDb  \
# 0           0   1                       Inception  2010  13+   8.8
# 1           1   2                      The Matrix  1999  18+   8.7
# 2           2   3          Avengers: Infinity War  2018  13+   8.5
# 3           3   4              Back to the Future  1985   7+   8.5
# 4           4   5  The Good, the Bad and the Ugly  1966  18+   8.8
#
#   Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  Type  \
# 0             87%        1     0            0        0     0
# 1             87%        1     0            0        0     0
# 2             84%        1     0            0        0     0
# 3             96%        1     0            0        0     0
# 4             97%        1     0            1        0     0
#
#                         Directors                            Genres  \
# 0               Christopher Nolan  Action,Adventure,Sci-Fi,Thriller
# ...

# %%
#Cleaning the dataset

df['Age'].replace(np.nan, "13+", inplace = True)
df['IMDb'].replace(np.nan, 0, inplace = True)
df['Rotten Tomatoes'].replace(np.nan, "0%", inplace = True)
df['Directors'].replace(np.nan, "unknown", inplace = True)
df['Genres'].replace(np.nan, "unknown", inplace = True)
df['Country'].replace(np.nan, "unknown", inplace = True)
df['Language'].replace(np.nan, "unknown", inplace = True)
df.dropna(subset = ['Runtime'], inplace = True)
df.drop(['Unnamed: 0'],axis = 1, inplace = True)
df.drop(['Type'], axis = 1, inplace = True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16152 entries, 0 to 16743
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               16152 non-null  int64
#  1   Title            16152 non-null  object
#  2   Year             16152 non-null  int64
#  3   Age              16152 non-null  object
#  4   IMDb             16152 non-null  float64
#  5   Rotten Tomatoes  16152 non-null  object
#  6   Netflix          16152 non-null  int64
#  7   Hulu             16152 non-null  int64
#  8   Prime Video      16152 non-null  int64
#  9   Disney+          16152 non-null  int64
#  10  Directors        16152 non-null  object
#  11  Genres           16152 non-null  object
#  12  Country          16152 non-null  object
#  13  Language         16152 non-null  object
#  14  Runtime          16152 non-null  float64
# dtypes: float64(2), int64(6), object(7)
# memory usage: 2.0+ MB

# %% [markdown]
# # Dataset Analysis using Pandas,Numpy & Visualisation using    Matplotlib

# %%
df.shape
# Out:
# (16152, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16152 entries, 0 to 16743
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               16152 non-null  int64
#  1   Title            16152 non-null  object
#  2   Year             16152 non-null  int64
#  3   Age              16152 non-null  object
#  4   IMDb             16152 non-null  float64
#  5   Rotten Tomatoes  16152 non-null  object
#  6   Netflix          16152 non-null  int64
#  7   Hulu             16152 non-null  int64
#  8   Prime Video      16152 non-null  int64
#  9   Disney+          16152 non-null  int64
#  10  Directors        16152 non-null  object
#  11  Genres           16152 non-null  object
#  12  Country          16152 non-null  object
#  13  Language         16152 non-null  object
#  14  Runtime          16152 non-null  float64
# dtypes: float64(2), int64(6), object(7)
# memory usage: 2.0+ MB

# %%
#df.rename(columns = {'Rotten Tomatoes'})
df.columns = df.columns.str.replace(' ', '_')
df.head()
# Out:
#    ID                           Title  Year  Age  IMDb Rotten_Tomatoes  \
# 0   1                       Inception  2010  13+   8.8             87%
# 1   2                      The Matrix  1999  18+   8.7             87%
# 2   3          Avengers: Infinity War  2018  13+   8.5             84%
# 3   4              Back to the Future  1985   7+   8.5             96%
# 4   5  The Good, the Bad and the Ugly  1966  18+   8.8             97%
#
#    Netflix  Hulu  Prime_Video  Disney+                       Directors  \
# 0        1     0            0        0               Christopher Nolan
# 1        1     0            0        0  Lana Wachowski,Lilly Wachowski
# 2        1     0            0        0         Anthony Russo,Joe Russo
# 3        1     0            0        0                 Robert Zemeckis
# 4        1     0            1        0                    Sergio Leone
#
#                              Genres                       Country  \
# ...

# %%
#family friendly movies
df.loc[(df.Age == 'all')]
# Out:
#           ID                                Title  Year  Age  IMDb  \
# 54        55  Willy Wonka & the Chocolate Factory  1971  all   7.8
# 91        92                               Tarzan  1999  all   7.3
# 125      126            The Princess and the Frog  2009  all   7.1
# 133      134                               Barfi!  2012  all   8.1
# 151      152                               Swades  2004  all   8.2
# ...      ...                                  ...   ...  ...   ...
# 16722  16723                      Secrets of Life  1956  all   7.2
# 16726  16727         Richie Rich's Christmas Wish  1998  all   4.1
# 16727  16728      The Jungle Book: Mowgli's Story  1998  all   4.2
# 16737  16738                      The Bears and I  1974  all   6.2
# 16738  16739         Whispers: An Elephant's Tale  2000  all   5.0
#
#       Rotten_Tomatoes  Netflix  Hulu  Prime_Video  Disney+  \
# 54                91%        1     0            0        0
# ...

# %%
# Age restricted or 18+ movies
df.loc[(df.Age == '18+')]
# Out:
#           ID                           Title  Year  Age  IMDb Rotten_Tomatoes  \
# 1          2                      The Matrix  1999  18+   8.7             87%
# 4          5  The Good, the Bad and the Ugly  1966  18+   8.8             97%
# 6          7                     The Pianist  2002  18+   8.5             95%
# 7          8                Django Unchained  2012  18+   8.4             87%
# 9         10            Inglourious Basterds  2009  18+   8.3             89%
# ...      ...                             ...   ...  ...   ...             ...
# 15847  15848                Rise of the Dead  2007  18+   3.0              0%
# 15851  15852                     The Wickeds  2005  18+   2.8              0%
# 15857  15858                Enemies Among Us  2010  18+   2.2              0%
# 15979  15980            Long Live Your Death  2015  18+   0.0              0%
# 16136  16137            Love & I Had A Fight  2013  18+   0.0              0%
#
# ...

# %%
#movie(s) with maximum runtime
max_runtime = df[['Title', 'Year', 'IMDb', 'Country', 'Language', 'Runtime']][df.Runtime == df['Runtime'].max()]
print(max_runtime)
# Out:
#           Title  Year  IMDb        Country Language  Runtime
# 13179  Colorado  1940   5.9  United States  English   1256.0

# %%
#movie(s) with minimum runtime
min_runtime = df[['Title', 'Year', 'IMDb', 'Country', 'Language', 'Runtime']][df.Runtime == df['Runtime'].min()]
print(min_runtime)
# Out:
#                    Title  Year  IMDb Country Language  Runtime
# 2626  Liefling The Movie  2010   6.3  Canada  English      1.0

# %%
# movie(s) that is/are available on Netflix, Prime Video as well as on Disney+
df.loc[(df['Netflix'] == 1) & (df['Prime_Video'] == 1) & (df['Disney+'] == 1)]
# Out:
#       ID Title  Year  Age  IMDb Rotten_Tomatoes  Netflix  Hulu  Prime_Video  \
# 103  104   Amy  2015  18+   7.8             95%        1     0            1
#
#      Disney+ Directors Genres        Country Language  Runtime
# 103        1   unknown  Drama  United States  English     60.0

# %%
# Print out Movie Names With highest IMDB ratings in the dataset

cf = df [['Title','IMDb']][df.IMDb==df['IMDb'].max()]
print(cf)
# Out:
#                                                   Title  IMDb
# 1292  My Next Guest with David Letterman and Shah Ru...   9.3
# 5110                                    Love on a Leash   9.3
# 6566                                         Square One   9.3
# 6837            Steven Banks: Home Entertainment Center   9.3
# 7220                                 Down, But Not Out!   9.3
# 7426                                             Bounty   9.3

# %%
#  Showing all Movies available in Hindi language
df.loc[(df['Language'].str.contains(pat = 'Hindi'))]
# Out:
#           ID                                 Title  Year  Age  IMDb  \
# 11        12                              3 Idiots  2009  13+   8.4
# 34        35                                Dangal  2016   7+   8.4
# 38        39                   Like Stars on Earth  2007   7+   8.4
# 44        45  Indiana Jones and the Temple of Doom  1984   7+   7.6
# 81        82     Lagaan: Once Upon a Time in India  2001   7+   8.1
# ...      ...                                   ...   ...  ...   ...
# 15807  15808                             Evil Eyes  2004  18+   3.3
# 15820  15821                   Escape From Taliban  2003  13+   4.5
# 15822  15823                               Machine  2007  18+   2.7
# 16227  16228            Captain America: Civil War  2016  13+   7.8
# 16455  16456           Around the World in 80 Days  2004   7+   5.9
#
#       Rotten_Tomatoes  Netflix  Hulu  Prime_Video  Disney+  \
# 11               100%        1     0            1        0
# ...

# %%
#Showing all the Indian Movies being streamed on these online platform
Movies = df.groupby('Country')
Ans = Movies.get_group('India')
Ans
# Out:
#           ID                              Title  Year  Age  IMDb  \
# 11        12                           3 Idiots  2009  13+   8.4
# 34        35                             Dangal  2016   7+   8.4
# 38        39                Like Stars on Earth  2007   7+   8.4
# 81        82  Lagaan: Once Upon a Time in India  2001   7+   8.1
# 88        89            Bahubali: The Beginning  2015  13+   8.1
# ...      ...                                ...   ...  ...   ...
# 15795  15796            Maan Gaye Mughal-e-Azam  2008  13+   3.1
# 15820  15821                Escape From Taliban  2003  13+   4.5
# 15822  15823                            Machine  2007  18+   2.7
# 15854  15855                  KAALA (Malayalam)  2018  13+   0.0
# 16064  16065                      Prathighatana  2014  13+   0.0
#
#       Rotten_Tomatoes  Netflix  Hulu  Prime_Video  Disney+  \
# 11               100%        1     0            1        0
# 34                88%        1     0            0        0
# ...

# %%
# Indian movie with highest rating on IMDb
Movies = df.groupby('Country')
Ind_movies = Movies.get_group('India')
highest = Ind_movies[['Title', 'Year', 'IMDb']][(Ind_movies.IMDb == Ind_movies['IMDb'].max())]
print(highest)
# Out:
#          Title  Year  IMDb
# 947  Natsamrat  2016   9.1

# %%
# Total movie share contributed by each OTT platform


netflix_movies=df.loc[df.Netflix==1]
total_netflix=len(netflix_movies)

prime_movies=df.loc[df.iloc[0:,8]==1]
total_prime=len(prime_movies)

hulu_movies=df.loc[df.Hulu==1]
total_hulu=len(hulu_movies)

disney_movies=df.loc[df.iloc[0:,9]==1]
total_disney=len(disney_movies)

labels=['Prime','Netflix','Disney','Hulu']
sizes=[total_prime,total_netflix,total_hulu,total_disney]
explode=(0.05,0.05,0.05,0.05)

fig1,ax1=plt.subplots()
ax1.pie(sizes,explode=explode,labels=labels,autopct="%1.1f%%",shadow=True)
ax1.axis('equal')
plt.title('Movie share between different OTT platforms')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#Identifying the oldest film in the given dataset which is streaming on these OTT platforms
df[['Title','Year']][df.Year==df['Year'].min()]
# Out:
#                    Title  Year
# 4467  A Trip to the Moon  1902

# %%
# all action genre movies
df.loc[df['Genres'].str.contains(pat = 'Action')]
# Out:
#           ID                               Title  Year  Age  IMDb  \
# 0          1                           Inception  2010  13+   8.8
# 1          2                          The Matrix  1999  18+   8.7
# 2          3              Avengers: Infinity War  2018  13+   8.5
# 5          6   Spider-Man: Into the Spider-Verse  2018   7+   8.4
# 8          9             Raiders of the Lost Ark  1981   7+   8.4
# ...      ...                                 ...   ...  ...   ...
# 16661  16662        Marvel Rising: Heart of Iron  2019  13+   4.0
# 16674  16675      Iron Man & Hulk: Heroes United  2013   7+   4.7
# 16684  16685      Marvel Rising: Operation Shuri  2019   7+   5.2
# 16686  16687  Marvel Rising: Battle of the Bands  2019  13+   5.0
# 16688  16689    Marvel Rising: Playing with Fire  2019   7+   5.3
#
#       Rotten_Tomatoes  Netflix  Hulu  Prime_Video  Disney+  \
# 0                 87%        1     0            0        0
# ...

# %%
# all animated movies
df.loc[df['Genres'].str.contains(pat = 'Animation')]
# Out:
#           ID                               Title  Year  Age  IMDb  \
# 5          6   Spider-Man: Into the Spider-Verse  2018   7+   8.4
# 33        34                       Incredibles 2  2018   7+   7.6
# 35        36                               Klaus  2019   7+   8.2
# 40        41                       Despicable Me  2010   7+   7.6
# 57        58                      A Silent Voice  2016  13+   8.2
# ...      ...                                 ...   ...  ...   ...
# 16674  16675      Iron Man & Hulk: Heroes United  2013   7+   4.7
# 16684  16685      Marvel Rising: Operation Shuri  2019   7+   5.2
# 16686  16687  Marvel Rising: Battle of the Bands  2019  13+   5.0
# 16688  16689    Marvel Rising: Playing with Fire  2019   7+   5.3
# 16719  16720                          Pocahontas  1995  13+   5.3
#
#       Rotten_Tomatoes  Netflix  Hulu  Prime_Video  Disney+  \
# 5                 97%        1     0            0        0
# ...

# %%
# all Indian comedy movies
df.loc[(df['Genres'].str.contains(pat = 'Comedy')) & (df['Country'] == 'India')]
# Out:
#           ID                     Title  Year  Age  IMDb Rotten_Tomatoes  \
# 11        12                  3 Idiots  2009  13+   8.4            100%
# 111      112                        PK  2014  13+   8.1             76%
# 115      116  Zindagi Na Milegi Dobara  2011   7+   8.1             91%
# 133      134                    Barfi!  2012  all   8.1             86%
# 155      156                    Padman  2018  13+   7.9            100%
# ...      ...                       ...   ...  ...   ...             ...
# 15367  15368                    Nayagi  2016  13+   2.9              0%
# 15487  15488        Mukkam Post London  2007  13+   4.6              0%
# 15692  15693  Shortkut - The Con Is On  2009  13+   3.4              0%
# 15784  15785            Gang Of Ghosts  2014  13+   3.6              0%
# 15795  15796   Maan Gaye Mughal-e-Azam  2008  13+   3.1              0%
#
#        Netflix  Hulu  Prime_Video  Disney+             Directors  \
# ...

# %%
# number of movies for each country
df['Country'].value_counts()
# Out:
# United States                                      8642
# India                                              1026
# United Kingdom                                      880
# Canada                                              548
# Australia                                           194
#                                                    ...
# Germany,Israel,Canada,United States                   1
# Switzerland,United Kingdom,France,United States       1
# France,United States,Canada,Russia                    1
# Argentina,Canada,China,Nepal,United States            1
# United Kingdom,Brazil,Germany                         1
# Name: Country, Length: 1299, dtype: int64

# %%
##Sorting out No of movies based on different genres available on these streaming platforms

df['Genres'].value_counts()
# Out:
# Drama                                         1297
# Documentary                                   1190
# Comedy                                         983
# Comedy,Drama                                   439
# Horror                                         433
#                                               ...
# Family,Mystery,Sport                             1
# Adventure,Family,Comedy                          1
# Action,Adventure,Horror,Mystery,Thriller         1
# Documentary,Biography,Comedy,Drama,History       1
# Documentary,Comedy,History                       1
# Name: Genres, Length: 1887, dtype: int64

# %% [markdown]
# # 2. Graphical visualisation of Data

# %%
netflix_movies=df.loc[df.Netflix==1]
total_netflix=len(netflix_movies)

prime_movies=df.loc[df.iloc[0:,8]==1]
total_prime=len(prime_movies)

hulu_movies=df.loc[df.Hulu==1]
total_hulu=len(hulu_movies)

disney_movies=df.loc[df.iloc[0:,9]==1]
total_disney=len(disney_movies)
def get_byYear(movie_dic):
    movie_years=np.array(movie_dic.iloc[0:,2],dtype=np.float)
    movies_by_year={}
    movies_after2015=[]
    for i in range(len(movie_years)):
        if(movie_years[i]>=2015):
            movies_after2015.append(movie_years[i])
    movies_after2015.sort()
    movies_after2015=np.array(movies_after2015,dtype=np.str)
    for i in range(len(movies_after2015)):
        if movies_after2015[i] in movies_by_year:
            movies_by_year[movies_after2015[i]]+=1
        else:
            movies_by_year[movies_after2015[i]]=1
    return movies_by_year

hulu_after2015=get_byYear(hulu_movies)
netflix_after2015=get_byYear(netflix_movies)
disney_after2015=get_byYear(disney_movies)
prime_after2015=get_byYear(prime_movies)
index=np.arange(6)
height1=list(netflix_after2015.values())
height2=list(prime_after2015.values())
height3=list(disney_after2015.values())
height4=list(hulu_after2015.values())
bar_width=0.25

plt.bar(index-1.5*bar_width, height1, label="Netflix", width=bar_width,align='center')
plt.bar(index-0.5*bar_width, height2, label="Amazon Prime", width=bar_width,align='center')
plt.bar(index+0.5*bar_width, height3, label="Disney+", width=bar_width,align='center')
plt.bar(index+1.5*bar_width, height4, label="Hulu", width=bar_width,align='center')

tick_label=list(netflix_after2015.keys())
plt.xticks(index, tick_label)
plt.title("Number of Movies released after 2015")
plt.legend()
plt.show()

# %%
def movie_genre(dic,num):
    genres=np.array(dic.iloc[0:,11],dtype=np.str)
    movie_genres={}
    for i in range(len(genres)):
        if genres[i] not in movie_genres:
            movie_genres[genres[i]]=1
        else:
            movie_genres[genres[i]]+=1
    movie_genres10={}
    for i in movie_genres.keys():
        if movie_genres[i]>=num:
            movie_genres10[i]=movie_genres[i]
    return movie_genres10

def avg_imdb(dic,genre):
    imdbs_df=dic.loc[dic.Genres==genre]
    imdbs=np.array(imdbs_df.iloc[0:,4],dtype=np.float)
    avg=np.mean(imdbs)
    return avg

def avg_of_genre_imdb(dic,num):
    pgenres=movie_genre(dic,num)
    newdic={}
    li=[]
    for i in pgenres.keys():
        if(i=="unknown"):
            continue
        a=avg_imdb(dic, i)
        li.append(pgenres[i])
        li.append(a)
        newdic[i]=li
        li=[]
    return newdic

def list_of(dic):
    size=[]
    aimdb=[]
    genre=list(dic.keys())
    genre.sort()
    for i in range(len(genre)):
        size.append(dic[genre[i]][0])
        aimdb.append(round(dic[genre[i]][1],2))
    return genre,size,aimdb

def plot_plots(movies,num):
    service_genres=avg_of_genre_imdb(movies,num)
    s_genre,s_size,net_imdb=list_of(service_genres)
    explode = ([0.05]*len(s_size))
    fig2, ax2 = plt.subplots()
    ax2.pie(s_size, explode=explode, labels=s_genre, autopct='%1.1f%%',
        shadow=True)
    ax2.axis('equal')
    plt.title("Percentage of movies of Top Genres")
    plt.show()
    plt.bar(range(len(s_genre)),net_imdb, color ='red',  
        width = 0.5)

    plt.xticks(range(len(s_genre)),s_genre,rotation=90)

    for i in range(len(s_genre)):
        plt.text(x = i-0.25, y = net_imdb[i]+0.1, s = net_imdb[i], size = 6)
  
    plt.xlabel("Most Popular Genres") 
    plt.ylabel("Average Imdb Rating") 
    plt.title("Average Imdb of Top Genres in Movies") 
    plt.show()

# %%
print("Netflix")
plot_plots(netflix_movies,35)
print()

print("Amazon Prime")
print()
plot_plots(prime_movies,150)

print("Disney+")
print()
plot_plots(disney_movies,10)

print("Hulu")
print()
plot_plots(hulu_movies, 25)
# Out:
# Netflix
# C:\Users\PANDIT\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3334: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\PANDIT\anaconda3\lib\site-packages\numpy\core\_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# ...
